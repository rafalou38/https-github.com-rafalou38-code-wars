# %% [markdown]
# <a href="https://colab.research.google.com/github/rafalou38/code-wars/blob/main/Scraping_Codewars_Top_500_Users.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![alt my_badge](https://www.codewars.com/users/darkrab/badges/large)](https://www.codewars.com/users/darkrab)
# # Scraping: Codewars Top 500 Users <img src="https://u.nu/kyu5" alt="4 kyu">
#
#
# - *02/01/2021*
# - **url:** https://www.codewars.com/kata/581c06b95cfa838603000435
# - **author:** 10XL
#
# -------
# ## task
# You should get and parse the html of the codewars leaderboard page.
#
# You can use `Nokogiri`(Ruby) or `BeautifulSoup`(Python) or `CheerioJS`(Javascript).
#
# For Javascript: Return a Promise resolved with your 'Leaderboard' Object!
#
# ## __**You must meet the following criteria:**__
#
# Return a 'Leaderboard' object with a position property.
#
# ```
# Leaderboard#position should contain 500 'User' objects.
# Leaderboard#position[i] should return the ith ranked User(1 based index).
# ```
#
# ###Each User should have the following properties:
#
# ```
# User#name    # => the user's username, not their real name
# User#clan    # => the user's clan, empty string if empty clan field
# User#honor   # => the user's honor points as an integer
# ```
# ##Example:
#
# ```
#   an_alien = leaderboard.position[3]   # => #<User:0x3124da0 @name="myjinxin2015", @clan="China Changyuan", @honor=21446>
#   an_alien.name                        # => "myjinxin2015"
#   an_alien.clan                        # => "China Changyuan"
#   an_alien.honor                       # => 21446
# ```

# %%
from bs4 import BeautifulSoup
import requests
from pprint import pprint
URL = 'https://www.codewars.com/users/leaderboard'

# this kata contains a error I have to use that :(
class cList:
    def __init__(self, items: list) -> None:
        self.items = items
    def __len__(self) -> int:
        return len(self.items)
    def __getitem__(self, key: int) -> any:
        return self.items[key - 1]

class User(object):
    def __init__(self, name,honor, clan=""):
        self.honor = honor
        self.name = name
        self.clan = clan
        
class leaderBorad(object):
    def fetch(self):
        self.position = []
        r = requests.get(URL)
        soup = BeautifulSoup(r.text, features="html.parser")
        for user in soup.select("[data-username]"):
            name = user["data-username"]
            _, _, clan, honor = user.select("td")
            self.position.append(
                User(
                    name=name,
                    honor=int(honor.text.replace(",", "")),
                    clan=clan.text,
                )
            )
        self.position = cList(self.position)
        
def solution():
   lead = leaderBorad()
   lead.fetch()
   return lead

# %%
import unittest

class TestCode(unittest.TestCase):
    leaderboard = solution()
    def test_should_have_a_size_of_500(self):
        self.assertEquals(len(self.leaderboard.position), 500)
    
    
    def test_should_contain_the_correct_names(self):
        # since these are hard coded, you should substitute with the current top 5
        self.assertEquals(self.leaderboard.position[1].name, 'g964')
        self.assertEquals(self.leaderboard.position[2].name, 'myjinxin2015')
        self.assertEquals(self.leaderboard.position[3].name, 'A.Partridge')
        self.assertEquals(self.leaderboard.position[4].name, 'jhoffner')
        self.assertEquals(self.leaderboard.position[5].name, 'Unnamed')
    
    
    def test_should_contain_the_correct_clan(self):
        # since these are hard coded, you should substitute with the current top 5
        self.assertEquals(self.leaderboard.position[1].clan, 'None')
        # self.assertEquals(leaderboard.position[2].clan, 'omitted')
        self.assertEquals(self.leaderboard.position[3].clan, 'Gensokyo')
        self.assertEquals(self.leaderboard.position[4].clan, 'CSV - SLayer')
        self.assertEquals(self.leaderboard.position[5].clan, 'PropertyExpert, Germany')
    
    
    def test_should_contain_the_correct_honor(self):
        # since these are hard coded, you should substitute with the current top 5
        self.assertEquals(self.leaderboard.position[1].honor > 110000, True)
        self.assertEquals(self.leaderboard.position[2].honor > 110000, True)
        self.assertEquals(self.leaderboard.position[3].honor > 60000, True)
        self.assertEquals(self.leaderboard.position[4].honor > 55000, True)
        self.assertEquals(self.leaderboard.position[5].honor > 50000, True)
    
if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: DeprecationWarning: Please use assertEqual instead.
# FE/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Please use assertEqual instead.
#   # This is added back by InteractiveShellApp.init_path()
# F/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: Please use assertEqual instead.
#
# .
# ...
# ERROR: test_should_contain_the_correct_honor (__main__.TestCode)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-13-5b0685bf0e27>", line 29, in test_should_contain_the_correct_honor
#     self.assertEquals(self.leaderboard.position[1].honor > 110000, True)
# TypeError: '>' not supported between instances of 'Tag' and 'int'
#
# ...
# FAIL: test_should_contain_the_correct_clan (__main__.TestCode)
# ----------------------------------------------------------------------
# ...
